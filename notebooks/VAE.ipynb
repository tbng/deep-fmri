# %% [markdown]
# <a href="https://colab.research.google.com/github/tbng/deep-fmri/blob/master/notebooks/VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
from pathlib import Path



drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
HCP_FOLDER = Path("/content/gdrive/My Drive/HCP_900")
MASKED_DATA_FILES = sorted(HCP_FOLDER.glob("*REST*.npy"))
MASKED_DATA_FILES
# Out:
# [PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_LR_0.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_LR_1.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_LR_2.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_LR_3.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_RL_0.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_RL_1.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_RL_2.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST1_RL_3.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_LR_0.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_LR_1.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_LR_2.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_LR_3.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_RL_0.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_RL_1.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_RL_2.npy'),
#  PosixPath('/content/gdrive/My Drive/HCP_900/100307_REST2_RL_3.npy')]

# %%
import glob

import numpy as np
import torch
from os.path import expanduser, join
from skimage.morphology import dilation, binary_dilation
from torch.utils.data import Dataset, ConcatDataset


class NumpyDataset(Dataset):
    def __init__(self, filename):
        self.filename = filename

    def __len__(self):
        return np.load(self.filename, mmap_mode='r').shape[3]

    def __getitem__(self, index):
        data = np.load(self.filename, mmap_mode='r')
        return torch.Tensor(data[None, :, :, :, index])


class NumpyDatasetMem(Dataset):
    def __init__(self, filename):
        self.data = torch.Tensor(np.load(filename, mmap_mode=None))

    def __len__(self):
        return self.data.shape[3]

    def __getitem__(self, index):
        return self.data[None, :, :, :, index]


def get_dataset(subject=100307, data_dir=None, in_memory=True):
    if in_memory:
        dataset_type = NumpyDatasetMem
    else:
        dataset_type = NumpyDataset
    if data_dir is None:
        data_dir = HCP_FOLDER
    datasets = [dataset_type(str(fp)) for fp in MASKED_DATA_FILES[:3]]
    train_dataset = ConcatDataset(datasets[:-1])
    test_dataset = datasets[-1]
    mask = np.load(data_dir / ('%s_mask.npy' % subject))
    mask = mask.astype('bool')
    print('Mask', mask.astype('float').sum(), 'voxels')
    for i in range(2):
        mask = binary_dilation(mask)
    mask = mask.astype('uint8')
    print('Dilated mask', mask.astype('float').sum(), 'voxels')
    mask = torch.from_numpy(mask).byte()

    return train_dataset, test_dataset, mask

# %%
import torch

import torch.nn as nn
import torch.nn.functional as F
from torch.testing import randn_like


class Encoder(nn.Module):
    def __init__(self, embedding_size=128):
        super().__init__()

        self.pad = nn.ConstantPad3d((2, 3, 9, 10, 2, 3), 0)
        self.conv = nn.Sequential(
            nn.Conv3d(1, 16, 3, 2, 1),
            nn.ReLU(),
            nn.Conv3d(16, 16, 3, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(16),

            nn.Conv3d(16, 32, 3, 2, 1),
            nn.ReLU(),
            nn.Conv3d(32, 32, 3, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(32),

            nn.Conv3d(32, 64, 3, 2, 1),
            nn.ReLU(),
            nn.Conv3d(64, 64, 3, 1, 1),
            nn.BatchNorm3d(64),
            nn.ReLU(),

            nn.Conv3d(64, 128, 3, 2, 1),
            nn.ReLU(),
            nn.Conv3d(128, 128, 3, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(128),

            nn.Conv3d(128, 256, 3, 2, 1),
            nn.ReLU(),
            nn.Conv3d(256, 256, 3, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(256),

        )

        self.dense = nn.Linear(256, embedding_size)
        self.dense_var = nn.Linear(256, embedding_size)

    def forward(self, img):
        batch_size = img.shape[0]
        img = self.pad(img)
        conv_img = self.conv(img)
        avg_channel = conv_img.view(batch_size, 256, -1).mean(dim=2)
        # avg_channel = F.dropout(avg_channel, p=0.1)
        mean = self.dense(avg_channel)
        log_var = self.dense_var(avg_channel)
        return mean, log_var


class Decoder(nn.Module):
    def __init__(self, embedding_size=128):
        super().__init__()

        self.dense = nn.Linear(embedding_size, 256)

        self.deconv = nn.Sequential(
            nn.ConvTranspose3d(256, 256, 3, 1, 1, 0),
            nn.ReLU(),
            nn.ConvTranspose3d(256, 128, 3, 2, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(128),

            nn.ConvTranspose3d(128, 128, 3, 1, 1, 0),
            nn.ReLU(),
            nn.ConvTranspose3d(128, 64, 3, 2, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(64),

            nn.ConvTranspose3d(64, 64, 3, 1, 1, 0),
            nn.ReLU(),
            nn.ConvTranspose3d(64, 32, 3, 2, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(32),

            nn.ConvTranspose3d(32, 32, 3, 1, 1, 0),
            nn.ReLU(),
            nn.ConvTranspose3d(32, 16, 3, 2, 1, 1),
            nn.ReLU(),
            nn.BatchNorm3d(16),

            nn.ConvTranspose3d(16, 16, 3, 1, 1, 0),
            nn.ReLU(),
            nn.ConvTranspose3d(16, 1, 3, 2, 1, 1)
        )

    def forward(self, latent):
        batch_size = latent.shape[0]
        avg_channel = self.dense(latent)
        # avg_channel = F.dropout(avg_channel, p=0.1)
        avg_channel = avg_channel[:, :, None,
                      None, None].expand(batch_size, 256, 3, 4, 3) * 1
        rec = self.deconv(avg_channel)

        # self.pad = nn.ConstantPad3d((2, 3, 9, 10, 2, 3), 0)
        rec = rec[:, :, 2:-3, 9:-10, 2:-3]
        return rec


class VAE(nn.Module):
    def __init__(self, embedding_dim=128):
        super().__init__()
        self.encoder = Encoder(embedding_dim)
        self.decoder = Decoder(embedding_dim)

    def forward(self, img):
        mean, log_var = self.encoder(img)
        penalty = gaussian_kl(mean, log_var)
        if self.training:
            eps = randn_like(mean)
            latent = mean + torch.exp(log_var / 2) * eps
        else:
            latent = mean
        return self.decoder(latent), penalty


def gaussian_kl(mean, log_var):
    return .5 * torch.sum(mean ** 2 + torch.exp(log_var)
                          - log_var - 1) / mean.shape[0]


def masked_mse(pred, target, mask):
    diff = pred - target
    mask = mask ^ 1
    mask = mask[None, None, ...]
    diff.masked_fill_(mask, 0.)
    return torch.sum(diff ** 2) / diff.shape[0]

# %%
import functools
import math

import torch
from os.path import expanduser
from torch.optim import Adam
from torch.utils.data import DataLoader
from torchsummary import summary


batch_size = 48
in_memory = True
alpha = 10
residual = False

train_dataset, test_dataset, mask = get_dataset(in_memory=in_memory)

train_loader = DataLoader(train_dataset, batch_size=batch_size,
                          shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size,
                         shuffle=False)
model = VAE()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
mask = mask.to(device)

summary(model, (1, 91, 109, 91))

loss_function = functools.partial(masked_mse, mask=mask)

optimizer = Adam(model.parameters(), lr=1e-3, amsgrad=True)

n_epochs = 100
total_loss = 0

n_batch = math.ceil(len(train_dataset) / batch_size)

mean = torch.zeros_like(train_dataset[0])
# Compute mean
if residual:
    length = 0
    for this_data in train_loader:
        length += this_data.shape[0]
        mean += this_data.sum(dim=0)
    mean /= length
mean = mean.to(device)

for epoch in range(n_epochs):
    epoch_batch = 0
    verbose_loss = 0
    verbose_penalty = 0
    verbose_batch = 0
    for this_data in train_loader:
        model.train()
        model.zero_grad()
        this_data[this_data >= 1] = 1
        this_data = this_data.to(device)
        this_data -= mean[None, ...]
        rec, penalty = model(this_data)
        penalty *= alpha
        loss = loss_function(rec, this_data)
        elbo = loss + penalty
        elbo.backward()
        optimizer.step()
        verbose_loss += loss.item()
        verbose_penalty += penalty.item()
        epoch_batch += 1
        verbose_batch += 1
        print('Epoch %i, batch %i/%i,'
                  'train_objective: %4e,'
                  'train_penalty: %4e,' % (epoch, epoch_batch, n_batch,
                                           verbose_loss / verbose_batch, 
                                           verbose_penalty / verbose_batch,))
        if epoch_batch % 10 == 0:
            model.eval()
            with torch.no_grad():
                val_batch = 0
                val_loss = 0
                val_penalty = 0
                for this_test_data in test_loader:
                    this_test_data = this_test_data.to(device)
                    this_test_data -= mean[None, ...]
                    rec, this_val_penalty = model(this_test_data)
                    this_val_penalty *= alpha
                    this_val_loss = loss_function(rec, this_test_data)
                    val_loss += this_val_loss.item()
                    val_penalty += this_val_penalty.item()
                    val_batch += 1
            val_loss /= val_batch
            val_penalty /= val_batch
            verbose_loss /= verbose_batch
            verbose_penalty /= verbose_batch
            print('Epoch %i, batch %i/%i,'
                  'train_objective: %4e,'
                  'train_penalty: %4e,'
                  'val_objective: %4e,'
                  'val_penalty: %4e' % (epoch, epoch_batch, n_batch,
                                        verbose_loss, verbose_penalty,
                                        val_loss, val_penalty))
            verbose_batch = 0
            train_loss = 0
            penalty = 0
    state_dict = model.state_dict()

    name = 'vae_dilated_e_%03i_loss_%.4e.pkl' % (epoch, verbose_loss)
    torch.save((state_dict, mean), name)
# Out:
# Mask 229399.0 voxels
# Dilated mask 270791.0 voxels
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#      ConstantPad3d-1       [-1, 1, 96, 128, 96]               0
#             Conv3d-2       [-1, 16, 48, 64, 48]             448
#               ReLU-3       [-1, 16, 48, 64, 48]               0
#             Conv3d-4       [-1, 16, 48, 64, 48]           6,928
#               ReLU-5       [-1, 16, 48, 64, 48]               0
#        BatchNorm3d-6       [-1, 16, 48, 64, 48]              32
#             Conv3d-7       [-1, 32, 24, 32, 24]          13,856
#               ReLU-8       [-1, 32, 24, 32, 24]               0
#             Conv3d-9       [-1, 32, 24, 32, 24]          27,680
#              ReLU-10       [-1, 32, 24, 32, 24]               0
#       BatchNorm3d-11       [-1, 32, 24, 32, 24]              64
#            Conv3d-12       [-1, 64, 12, 16, 12]          55,360
#              ReLU-13       [-1, 64, 12, 16, 12]               0
#            Conv3d-14       [-1, 64, 12, 16, 12]         110,656
#       BatchNorm3d-15       [-1, 64, 12, 16, 12]             128
#              ReLU-16       [-1, 64, 12, 16, 12]               0
#            Conv3d-17         [-1, 128, 6, 8, 6]         221,312
#              ReLU-18         [-1, 128, 6, 8, 6]               0
#            Conv3d-19         [-1, 128, 6, 8, 6]         442,496
#              ReLU-20         [-1, 128, 6, 8, 6]               0
#       BatchNorm3d-21         [-1, 128, 6, 8, 6]             256
#            Conv3d-22         [-1, 256, 3, 4, 3]         884,992
#              ReLU-23         [-1, 256, 3, 4, 3]               0
#            Conv3d-24         [-1, 256, 3, 4, 3]       1,769,728
#              ReLU-25         [-1, 256, 3, 4, 3]               0
#       BatchNorm3d-26         [-1, 256, 3, 4, 3]             512
#            Linear-27                  [-1, 128]          32,896
#            Linear-28                  [-1, 128]          32,896
#           Encoder-29     [[-1, 128], [-1, 128]]               0
#            Linear-30                  [-1, 256]          33,024
#   ConvTranspose3d-31         [-1, 256, 3, 4, 3]       1,769,728
#              ReLU-32         [-1, 256, 3, 4, 3]               0
#   ConvTranspose3d-33         [-1, 128, 6, 8, 6]         884,864
#              ReLU-34         [-1, 128, 6, 8, 6]               0
#       BatchNorm3d-35         [-1, 128, 6, 8, 6]             256
#   ConvTranspose3d-36         [-1, 128, 6, 8, 6]         442,496
#              ReLU-37         [-1, 128, 6, 8, 6]               0
#   ConvTranspose3d-38       [-1, 64, 12, 16, 12]         221,248
#              ReLU-39       [-1, 64, 12, 16, 12]               0
#       BatchNorm3d-40       [-1, 64, 12, 16, 12]             128
#   ConvTranspose3d-41       [-1, 64, 12, 16, 12]         110,656
#              ReLU-42       [-1, 64, 12, 16, 12]               0
#   ConvTranspose3d-43       [-1, 32, 24, 32, 24]          55,328
#              ReLU-44       [-1, 32, 24, 32, 24]               0
#       BatchNorm3d-45       [-1, 32, 24, 32, 24]              64
#   ConvTranspose3d-46       [-1, 32, 24, 32, 24]          27,680
#              ReLU-47       [-1, 32, 24, 32, 24]               0
#   ConvTranspose3d-48       [-1, 16, 48, 64, 48]          13,840
#              ReLU-49       [-1, 16, 48, 64, 48]               0
#       BatchNorm3d-50       [-1, 16, 48, 64, 48]              32
#   ConvTranspose3d-51       [-1, 16, 48, 64, 48]           6,928
#              ReLU-52       [-1, 16, 48, 64, 48]               0
#   ConvTranspose3d-53       [-1, 1, 96, 128, 96]             433
#           Decoder-54       [-1, 1, 91, 109, 91]               0
# ================================================================
# Total params: 7,166,945
# Trainable params: 7,166,945
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.44
# Forward/backward pass size (MB): 264.32
# Params size (MB): 27.34
# Estimated Total Size (MB): 295.10
# ----------------------------------------------------------------
# Epoch 0, batch 1/13,train_objective: 1.416764e+05,train_penalty: 1.658774e+00,
# Epoch 0, batch 2/13,train_objective: 1.298170e+05,train_penalty: 1.528693e+00,
# Epoch 0, batch 3/13,train_objective: 1.230080e+05,train_penalty: 1.461508e+00,
# Epoch 0, batch 4/13,train_objective: 1.173305e+05,train_penalty: 1.420085e+00,
# Epoch 0, batch 5/13,train_objective: 1.118568e+05,train_penalty: 1.393677e+00,
# Epoch 0, batch 6/13,train_objective: 1.064457e+05,train_penalty: 1.376150e+00,
# Epoch 0, batch 7/13,train_objective: 1.014218e+05,train_penalty: 1.362906e+00,
# Epoch 0, batch 8/13,train_objective: 9.705367e+04,train_penalty: 1.352761e+00,
# Epoch 0, batch 9/13,train_objective: 9.306252e+04,train_penalty: 1.345458e+00,
# Epoch 0, batch 10/13,train_objective: 8.953856e+04,train_penalty: 1.340731e+00,
# Epoch 0, batch 10/13,train_objective: 8.953856e+04,train_penalty: 1.340731e+00,val_objective: 1.061840e+05,val_penalty: 3.131797e+00
# Epoch 0, batch 11/13,train_objective: 1.440589e+05,train_penalty: 2.649528e+00,
# Epoch 0, batch 12/13,train_objective: 9.778594e+04,train_penalty: 1.982107e+00,
# Epoch 0, batch 13/13,train_objective: 8.151692e+04,train_penalty: 1.763924e+00,
# Epoch 1, batch 1/13,train_objective: 4.642675e+04,train_penalty: 1.335983e+00,
# Epoch 1, batch 2/13,train_objective: 4.520275e+04,train_penalty: 1.339306e+00,
# Epoch 1, batch 3/13,train_objective: 4.402539e+04,train_penalty: 1.345111e+00,
# Epoch 1, batch 4/13,train_objective: 4.290544e+04,train_penalty: 1.350537e+00,
# Epoch 1, batch 5/13,train_objective: 4.181483e+04,train_penalty: 1.356004e+00,
# Epoch 1, batch 6/13,train_objective: 4.077778e+04,train_penalty: 1.361311e+00,
# Epoch 1, batch 7/13,train_objective: 3.975731e+04,train_penalty: 1.366365e+00,
# Epoch 1, batch 8/13,train_objective: 3.877198e+04,train_penalty: 1.371286e+00,
# Epoch 1, batch 9/13,train_objective: 3.781319e+04,train_penalty: 1.376739e+00,
# Epoch 1, batch 10/13,train_objective: 3.687011e+04,train_penalty: 1.382409e+00,
# Epoch 1, batch 10/13,train_objective: 3.687011e+04,train_penalty: 1.382409e+00,val_objective: 4.837685e+04,val_penalty: 3.286091e+01
# Epoch 1, batch 11/13,train_objective: 6.350358e+04,train_penalty: 2.828501e+00,
# Epoch 1, batch 12/13,train_objective: 4.418677e+04,train_penalty: 2.146697e+00,
# Epoch 1, batch 13/13,train_objective: 3.719027e+04,train_penalty: 1.925113e+00,
# Epoch 2, batch 1/13,train_objective: 2.156218e+04,train_penalty: 1.504123e+00,
# Epoch 2, batch 2/13,train_objective: 2.085658e+04,train_penalty: 1.514689e+00,
# Epoch 2, batch 3/13,train_objective: 2.018689e+04,train_penalty: 1.526433e+00,
# Epoch 2, batch 4/13,train_objective: 1.956858e+04,train_penalty: 1.539319e+00,
# Epoch 2, batch 5/13,train_objective: 1.904362e+04,train_penalty: 1.551977e+00,
# Epoch 2, batch 6/13,train_objective: 1.858567e+04,train_penalty: 1.566552e+00,
# Epoch 2, batch 7/13,train_objective: 1.815473e+04,train_penalty: 1.582120e+00,
# Epoch 2, batch 8/13,train_objective: 1.776290e+04,train_penalty: 1.598773e+00,
# Epoch 2, batch 9/13,train_objective: 1.741627e+04,train_penalty: 1.617555e+00,
# Epoch 2, batch 10/13,train_objective: 1.708031e+04,train_penalty: 1.637667e+00,
# Epoch 2, batch 10/13,train_objective: 1.708031e+04,train_penalty: 1.637667e+00,val_objective: 1.490711e+04,val_penalty: 5.842121e+01
# Epoch 2, batch 11/13,train_objective: 3.059913e+04,train_penalty: 3.518788e+00,
# Epoch 2, batch 12/13,train_objective: 2.183626e+04,train_penalty: 2.729047e+00,
# Epoch 2, batch 13/13,train_objective: 1.872909e+04,train_penalty: 2.490882e+00,
# Epoch 3, batch 1/13,train_objective: 1.213424e+04,train_penalty: 2.086196e+00,
# Epoch 3, batch 2/13,train_objective: 1.186457e+04,train_penalty: 2.126305e+00,
# Epoch 3, batch 3/13,train_objective: 1.162886e+04,train_penalty: 2.169992e+00,
# Epoch 3, batch 4/13,train_objective: 1.144391e+04,train_penalty: 2.218729e+00,
# Epoch 3, batch 5/13,train_objective: 1.128366e+04,train_penalty: 2.267708e+00,
# Epoch 3, batch 6/13,train_objective: 1.113594e+04,train_penalty: 2.318252e+00,
# Epoch 3, batch 7/13,train_objective: 1.097335e+04,train_penalty: 2.369888e+00,
# Epoch 3, batch 8/13,train_objective: 1.080690e+04,train_penalty: 2.423492e+00,
# Epoch 3, batch 9/13,train_objective: 1.067308e+04,train_penalty: 2.477465e+00,
# Epoch 3, batch 10/13,train_objective: 1.054702e+04,train_penalty: 2.530117e+00,
# Epoch 3, batch 10/13,train_objective: 1.054702e+04,train_penalty: 2.530117e+00,val_objective: 1.095384e+04,val_penalty: 1.022275e+02
# Epoch 3, batch 11/13,train_objective: 1.963958e+04,train_penalty: 5.640002e+00,
# Epoch 3, batch 12/13,train_objective: 1.417173e+04,train_penalty: 4.425792e+00,
# Epoch 3, batch 13/13,train_objective: 1.237059e+04,train_penalty: 4.045975e+00,
# Epoch 4, batch 1/13,train_objective: 8.518777e+03,train_penalty: 3.382815e+00,
# Epoch 4, batch 2/13,train_objective: 8.417680e+03,train_penalty: 3.425211e+00,
# Epoch 4, batch 3/13,train_objective: 8.359415e+03,train_penalty: 3.473042e+00,
# Epoch 4, batch 4/13,train_objective: 8.324136e+03,train_penalty: 3.524560e+00,
# Epoch 4, batch 5/13,train_objective: 8.237782e+03,train_penalty: 3.576389e+00,
# Epoch 4, batch 6/13,train_objective: 8.183896e+03,train_penalty: 3.629928e+00,
# Epoch 4, batch 7/13,train_objective: 8.132934e+03,train_penalty: 3.683650e+00,
# Epoch 4, batch 8/13,train_objective: 8.071481e+03,train_penalty: 3.738548e+00,
# Epoch 4, batch 9/13,train_objective: 8.022165e+03,train_penalty: 3.794729e+00,
# Epoch 4, batch 10/13,train_objective: 7.969784e+03,train_penalty: 3.850469e+00,
# Epoch 4, batch 10/13,train_objective: 7.969784e+03,train_penalty: 3.850469e+00,val_objective: 1.893936e+04,val_penalty: 1.808523e+01
# Epoch 4, batch 11/13,train_objective: 1.540139e+04,train_penalty: 8.301896e+00,
# Epoch 4, batch 12/13,train_objective: 1.135896e+04,train_penalty: 6.423777e+00,
# Epoch 4, batch 13/13,train_objective: 1.000176e+04,train_penalty: 5.826687e+00,
# Epoch 5, batch 1/13,train_objective: 7.137076e+03,train_penalty: 4.719620e+00,
# Epoch 5, batch 2/13,train_objective: 7.164721e+03,train_penalty: 4.756567e+00,
# Epoch 5, batch 3/13,train_objective: 7.109478e+03,train_penalty: 4.790614e+00,
# Epoch 5, batch 4/13,train_objective: 7.093791e+03,train_penalty: 4.822756e+00,
# Epoch 5, batch 5/13,train_objective: 7.060753e+03,train_penalty: 4.852380e+00,
# Epoch 5, batch 6/13,train_objective: 7.028442e+03,train_penalty: 4.880263e+00,
# Epoch 5, batch 7/13,train_objective: 7.002442e+03,train_penalty: 4.906986e+00,
# Epoch 5, batch 8/13,train_objective: 6.970504e+03,train_penalty: 4.933197e+00,
# Epoch 5, batch 9/13,train_objective: 6.937594e+03,train_penalty: 4.958039e+00,
# Epoch 5, batch 10/13,train_objective: 6.909646e+03,train_penalty: 4.981946e+00,
# Epoch 5, batch 10/13,train_objective: 6.909646e+03,train_penalty: 4.981946e+00,val_objective: 1.837125e+04,val_penalty: 4.192709e+00
# Epoch 5, batch 11/13,train_objective: 1.358978e+04,train_penalty: 1.021303e+01,
# Epoch 5, batch 12/13,train_objective: 1.017130e+04,train_penalty: 7.739167e+00,
# Epoch 5, batch 13/13,train_objective: 9.250931e+03,train_penalty: 6.922309e+00,
# Epoch 6, batch 1/13,train_objective: 8.086460e+03,train_penalty: 5.300364e+00,
# Epoch 6, batch 2/13,train_objective: 7.315793e+03,train_penalty: 5.285962e+00,
# Epoch 6, batch 3/13,train_objective: 7.369410e+03,train_penalty: 5.274199e+00,
# Epoch 6, batch 4/13,train_objective: 7.186151e+03,train_penalty: 5.267273e+00,
# Epoch 6, batch 5/13,train_objective: 7.144598e+03,train_penalty: 5.261356e+00,
# Epoch 6, batch 6/13,train_objective: 7.061408e+03,train_penalty: 5.251370e+00,
# Epoch 6, batch 7/13,train_objective: 6.994943e+03,train_penalty: 5.239570e+00,
# Epoch 6, batch 8/13,train_objective: 6.953934e+03,train_penalty: 5.227244e+00,
# Epoch 6, batch 9/13,train_objective: 6.890303e+03,train_penalty: 5.216284e+00,
# Epoch 6, batch 10/13,train_objective: 6.848826e+03,train_penalty: 5.206044e+00,
# Epoch 6, batch 10/13,train_objective: 6.848826e+03,train_penalty: 5.206044e+00,val_objective: 1.758883e+04,val_penalty: 1.794892e+01
# Epoch 6, batch 11/13,train_objective: 1.326297e+04,train_penalty: 1.029354e+01,
# Epoch 6, batch 12/13,train_objective: 9.710519e+03,train_penalty: 7.676591e+00,
# Epoch 6, batch 13/13,train_objective: 8.574793e+03,train_penalty: 6.796994e+00,
# Epoch 7, batch 1/13,train_objective: 6.112069e+03,train_penalty: 5.015099e+00,
# Epoch 7, batch 2/13,train_objective: 6.109725e+03,train_penalty: 5.001975e+00,
# Epoch 7, batch 3/13,train_objective: 6.106138e+03,train_penalty: 4.983954e+00,
# Epoch 7, batch 4/13,train_objective: 6.062744e+03,train_penalty: 4.959455e+00,
# Epoch 7, batch 5/13,train_objective: 6.045322e+03,train_penalty: 4.934410e+00,
# Epoch 7, batch 6/13,train_objective: 6.021091e+03,train_penalty: 4.909939e+00,
# Epoch 7, batch 7/13,train_objective: 5.988304e+03,train_penalty: 4.884862e+00,
# Epoch 7, batch 8/13,train_objective: 5.971135e+03,train_penalty: 4.859327e+00,
# Epoch 7, batch 9/13,train_objective: 5.944700e+03,train_penalty: 4.832165e+00,
# Epoch 7, batch 10/13,train_objective: 5.921447e+03,train_penalty: 4.805196e+00,
# Epoch 7, batch 10/13,train_objective: 5.921447e+03,train_penalty: 4.805196e+00,val_objective: 2.621707e+04,val_penalty: 1.021464e+01
# Epoch 7, batch 11/13,train_objective: 1.154078e+04,train_penalty: 9.301956e+00,
# Epoch 7, batch 12/13,train_objective: 8.598655e+03,train_penalty: 6.871801e+00,
# Epoch 7, batch 13/13,train_objective: 7.577191e+03,train_penalty: 6.039477e+00,
# Epoch 8, batch 1/13,train_objective: 5.493521e+03,train_penalty: 4.312563e+00,
# Epoch 8, batch 2/13,train_objective: 5.485731e+03,train_penalty: 4.282736e+00,
# Epoch 8, batch 3/13,train_objective: 5.459781e+03,train_penalty: 4.253142e+00,
# Epoch 8, batch 4/13,train_objective: 5.425281e+03,train_penalty: 4.225648e+00,
# Epoch 8, batch 5/13,train_objective: 5.401921e+03,train_penalty: 4.198743e+00,
# Epoch 8, batch 6/13,train_objective: 5.379529e+03,train_penalty: 4.170837e+00,
# Epoch 8, batch 7/13,train_objective: 5.356000e+03,train_penalty: 4.142262e+00,
# Epoch 8, batch 8/13,train_objective: 5.334404e+03,train_penalty: 4.112987e+00,
# Epoch 8, batch 9/13,train_objective: 5.318726e+03,train_penalty: 4.083590e+00,
# Epoch 8, batch 10/13,train_objective: 5.306692e+03,train_penalty: 4.054446e+00,
# Epoch 8, batch 10/13,train_objective: 5.306692e+03,train_penalty: 4.054446e+00,val_objective: 2.337688e+04,val_penalty: 3.601445e+00
# Epoch 8, batch 11/13,train_objective: 1.076866e+04,train_penalty: 7.801985e+00,
# Epoch 8, batch 12/13,train_objective: 8.595204e+03,train_penalty: 5.751775e+00,
# Epoch 8, batch 13/13,train_objective: 7.928615e+03,train_penalty: 5.051267e+00,
# Epoch 9, batch 1/13,train_objective: 5.056950e+03,train_penalty: 3.587833e+00,
# Epoch 9, batch 2/13,train_objective: 5.580612e+03,train_penalty: 3.562239e+00,
# Epoch 9, batch 3/13,train_objective: 5.414866e+03,train_penalty: 3.543134e+00,
# Epoch 9, batch 4/13,train_objective: 5.478727e+03,train_penalty: 3.527918e+00,
# Epoch 9, batch 5/13,train_objective: 5.421267e+03,train_penalty: 3.508055e+00,
# Epoch 9, batch 6/13,train_objective: 5.400552e+03,train_penalty: 3.485907e+00,
# Epoch 9, batch 7/13,train_objective: 5.393133e+03,train_penalty: 3.463818e+00,
# Epoch 9, batch 8/13,train_objective: 5.339245e+03,train_penalty: 3.442587e+00,
# Epoch 9, batch 9/13,train_objective: 5.327544e+03,train_penalty: 3.421847e+00,
# Epoch 9, batch 10/13,train_objective: 5.287462e+03,train_penalty: 3.400300e+00,
# Epoch 9, batch 10/13,train_objective: 5.287462e+03,train_penalty: 3.400300e+00,val_objective: 2.675472e+04,val_penalty: 6.300911e+00
# Epoch 9, batch 11/13,train_objective: 1.024604e+04,train_penalty: 6.548966e+00,
# Epoch 9, batch 12/13,train_objective: 7.575519e+03,train_penalty: 4.823334e+00,
# Epoch 9, batch 13/13,train_objective: 6.646964e+03,train_penalty: 4.233746e+00,
# Epoch 10, batch 1/13,train_objective: 4.871853e+03,train_penalty: 3.013012e+00,
# Epoch 10, batch 2/13,train_objective: 4.774303e+03,train_penalty: 2.990298e+00,
# Epoch 10, batch 3/13,train_objective: 4.746430e+03,train_penalty: 2.964288e+00,
# Epoch 10, batch 4/13,train_objective: 4.722849e+03,train_penalty: 2.942098e+00,
# Epoch 10, batch 5/13,train_objective: 4.690458e+03,train_penalty: 2.921863e+00,
# Epoch 10, batch 6/13,train_objective: 4.671626e+03,train_penalty: 2.903351e+00,
# Epoch 10, batch 7/13,train_objective: 4.645699e+03,train_penalty: 2.885272e+00,
# Epoch 10, batch 8/13,train_objective: 4.627945e+03,train_penalty: 2.867512e+00,
# Epoch 10, batch 9/13,train_objective: 4.605340e+03,train_penalty: 2.849993e+00,
# Epoch 10, batch 10/13,train_objective: 4.585418e+03,train_penalty: 2.832408e+00,
# Epoch 10, batch 10/13,train_objective: 4.585418e+03,train_penalty: 2.832408e+00,val_objective: 2.623016e+04,val_penalty: 2.815131e+00
# Epoch 10, batch 11/13,train_objective: 8.931553e+03,train_penalty: 5.474190e+00,
# Epoch 10, batch 12/13,train_objective: 6.621511e+03,train_penalty: 4.043297e+00,
# Epoch 10, batch 13/13,train_objective: 5.853063e+03,train_penalty: 3.555636e+00,
# Epoch 11, batch 1/13,train_objective: 4.239056e+03,train_penalty: 2.561595e+00,
# Epoch 11, batch 2/13,train_objective: 4.242204e+03,train_penalty: 2.549196e+00,
# Epoch 11, batch 3/13,train_objective: 4.223852e+03,train_penalty: 2.534132e+00,
# Epoch 11, batch 4/13,train_objective: 4.216770e+03,train_penalty: 2.519540e+00,
# Epoch 11, batch 5/13,train_objective: 4.204001e+03,train_penalty: 2.505714e+00,
# Epoch 11, batch 6/13,train_objective: 4.189621e+03,train_penalty: 2.492808e+00,
# Epoch 11, batch 7/13,train_objective: 4.172337e+03,train_penalty: 2.480211e+00,
# Epoch 11, batch 8/13,train_objective: 4.159093e+03,train_penalty: 2.468219e+00,
# Epoch 11, batch 9/13,train_objective: 4.148600e+03,train_penalty: 2.456158e+00,
# Epoch 11, batch 10/13,train_objective: 4.139246e+03,train_penalty: 2.444174e+00,
# Epoch 11, batch 10/13,train_objective: 4.139246e+03,train_penalty: 2.444174e+00,val_objective: 2.085884e+04,val_penalty: 3.903342e+00
# Epoch 11, batch 11/13,train_objective: 8.168949e+03,train_penalty: 4.754535e+00,
# Epoch 11, batch 12/13,train_objective: 6.086154e+03,train_penalty: 3.520624e+00,
# Epoch 11, batch 13/13,train_objective: 5.371099e+03,train_penalty: 3.099562e+00,
# Epoch 12, batch 1/13,train_objective: 3.901402e+03,train_penalty: 2.235891e+00,
# Epoch 12, batch 2/13,train_objective: 3.884990e+03,train_penalty: 2.223295e+00,
# Epoch 12, batch 3/13,train_objective: 3.879218e+03,train_penalty: 2.210284e+00,
# Epoch 12, batch 4/13,train_objective: 3.880149e+03,train_penalty: 2.197004e+00,
# Epoch 12, batch 5/13,train_objective: 3.879881e+03,train_penalty: 2.183805e+00,
# Epoch 12, batch 6/13,train_objective: 3.881480e+03,train_penalty: 2.171000e+00,
# Epoch 12, batch 7/13,train_objective: 3.889086e+03,train_penalty: 2.158293e+00,
# Epoch 12, batch 8/13,train_objective: 3.884514e+03,train_penalty: 2.145982e+00,
# Epoch 12, batch 9/13,train_objective: 3.873110e+03,train_penalty: 2.133981e+00,
# Epoch 12, batch 10/13,train_objective: 3.859305e+03,train_penalty: 2.121326e+00,
# Epoch 12, batch 10/13,train_objective: 3.859305e+03,train_penalty: 2.121326e+00,val_objective: 1.706096e+04,val_penalty: 4.486557e+00
# Epoch 12, batch 11/13,train_objective: 7.608592e+03,train_penalty: 4.105153e+00,
# Epoch 12, batch 12/13,train_objective: 5.688033e+03,train_penalty: 3.032417e+00,
# Epoch 12, batch 13/13,train_objective: 5.031417e+03,train_penalty: 2.665895e+00,
# Epoch 13, batch 1/13,train_objective: 3.689221e+03,train_penalty: 1.912187e+00,
# Epoch 13, batch 2/13,train_objective: 3.677269e+03,train_penalty: 1.899307e+00,
# Epoch 13, batch 3/13,train_objective: 3.666385e+03,train_penalty: 1.887313e+00,
# Epoch 13, batch 4/13,train_objective: 3.663577e+03,train_penalty: 1.874957e+00,
# Epoch 13, batch 5/13,train_objective: 3.659534e+03,train_penalty: 1.863391e+00,
# Epoch 13, batch 6/13,train_objective: 3.649814e+03,train_penalty: 1.851942e+00,
# Epoch 13, batch 7/13,train_objective: 3.637302e+03,train_penalty: 1.840733e+00,
# Epoch 13, batch 8/13,train_objective: 3.626925e+03,train_penalty: 1.829656e+00,
# Epoch 13, batch 9/13,train_objective: 3.621255e+03,train_penalty: 1.818543e+00,
# Epoch 13, batch 10/13,train_objective: 3.615032e+03,train_penalty: 1.807498e+00,
# Epoch 13, batch 10/13,train_objective: 3.615032e+03,train_penalty: 1.807498e+00,val_objective: 1.669036e+04,val_penalty: 2.670319e+00
# Epoch 13, batch 11/13,train_objective: 7.114774e+03,train_penalty: 3.497079e+00,
# Epoch 13, batch 12/13,train_objective: 5.321210e+03,train_penalty: 2.583627e+00,
# Epoch 13, batch 13/13,train_objective: 4.745867e+03,train_penalty: 2.273138e+00,
# Epoch 14, batch 1/13,train_objective: 3.600883e+03,train_penalty: 1.629616e+00,
# Epoch 14, batch 2/13,train_objective: 3.596536e+03,train_penalty: 1.621119e+00,
# Epoch 14, batch 3/13,train_objective: 3.590862e+03,train_penalty: 1.612274e+00,
# Epoch 14, batch 4/13,train_objective: 3.567114e+03,train_penalty: 1.603201e+00,
# Epoch 14, batch 5/13,train_objective: 3.535804e+03,train_penalty: 1.594423e+00,
# Epoch 14, batch 6/13,train_objective: 3.517303e+03,train_penalty: 1.584940e+00,
# Epoch 14, batch 7/13,train_objective: 3.508822e+03,train_penalty: 1.576060e+00,
# Epoch 14, batch 8/13,train_objective: 3.497684e+03,train_penalty: 1.566902e+00,
# Epoch 14, batch 9/13,train_objective: 3.488698e+03,train_penalty: 1.557454e+00,
# Epoch 14, batch 10/13,train_objective: 3.491074e+03,train_penalty: 1.548185e+00,
# Epoch 14, batch 10/13,train_objective: 3.491074e+03,train_penalty: 1.548185e+00,val_objective: 1.227422e+04,val_penalty: 1.822907e+00
# Epoch 14, batch 11/13,train_objective: 7.017154e+03,train_penalty: 2.994338e+00,
# Epoch 14, batch 12/13,train_objective: 5.176230e+03,train_penalty: 2.212900e+00,
# Epoch 14, batch 13/13,train_objective: 4.597830e+03,train_penalty: 1.944900e+00,
# Epoch 15, batch 1/13,train_objective: 3.462884e+03,train_penalty: 1.394729e+00,
# Epoch 15, batch 2/13,train_objective: 3.390934e+03,train_penalty: 1.386676e+00,
# Epoch 15, batch 3/13,train_objective: 3.401652e+03,train_penalty: 1.378413e+00,
# Epoch 15, batch 4/13,train_objective: 3.390875e+03,train_penalty: 1.370770e+00,
# Epoch 15, batch 5/13,train_objective: 3.372933e+03,train_penalty: 1.362621e+00,
# Epoch 15, batch 6/13,train_objective: 3.373050e+03,train_penalty: 1.354874e+00,
# Epoch 15, batch 7/13,train_objective: 3.358196e+03,train_penalty: 1.347696e+00,
# Epoch 15, batch 8/13,train_objective: 3.351587e+03,train_penalty: 1.340399e+00,
# Epoch 15, batch 9/13,train_objective: 3.343181e+03,train_penalty: 1.333053e+00,
# Epoch 15, batch 10/13,train_objective: 3.335526e+03,train_penalty: 1.325720e+00,
# Epoch 15, batch 10/13,train_objective: 3.335526e+03,train_penalty: 1.325720e+00,val_objective: 1.192525e+04,val_penalty: 1.248706e+00
# Epoch 15, batch 11/13,train_objective: 6.617426e+03,train_penalty: 2.573461e+00,
# Epoch 15, batch 12/13,train_objective: 4.913779e+03,train_penalty: 1.903180e+00,
# Epoch 15, batch 13/13,train_objective: 4.357486e+03,train_penalty: 1.675348e+00,
# Epoch 16, batch 1/13,train_objective: 3.191320e+03,train_penalty: 1.207352e+00,
# Epoch 16, batch 2/13,train_objective: 3.191608e+03,train_penalty: 1.200177e+00,
# Epoch 16, batch 3/13,train_objective: 3.187600e+03,train_penalty: 1.193680e+00,
# Epoch 16, batch 4/13,train_objective: 3.178820e+03,train_penalty: 1.186981e+00,
# Epoch 16, batch 5/13,train_objective: 3.176695e+03,train_penalty: 1.180172e+00,
# Epoch 16, batch 6/13,train_objective: 3.169378e+03,train_penalty: 1.173497e+00,
# Epoch 16, batch 7/13,train_objective: 3.164556e+03,train_penalty: 1.166915e+00,
# Epoch 16, batch 8/13,train_objective: 3.160859e+03,train_penalty: 1.160621e+00,
# Epoch 16, batch 9/13,train_objective: 3.155213e+03,train_penalty: 1.154574e+00,
# Epoch 16, batch 10/13,train_objective: 3.153249e+03,train_penalty: 1.148169e+00,
# Epoch 16, batch 10/13,train_objective: 3.153249e+03,train_penalty: 1.148169e+00,val_objective: 1.156975e+04,val_penalty: 1.082800e+00
# Epoch 16, batch 11/13,train_objective: 6.335419e+03,train_penalty: 2.226557e+00,
# Epoch 16, batch 12/13,train_objective: 4.816050e+03,train_penalty: 1.647195e+00,
# Epoch 16, batch 13/13,train_objective: 4.334978e+03,train_penalty: 1.451443e+00,
# Epoch 17, batch 1/13,train_objective: 3.121521e+03,train_penalty: 1.047384e+00,
# Epoch 17, batch 2/13,train_objective: 3.133549e+03,train_penalty: 1.042405e+00,
# Epoch 17, batch 3/13,train_objective: 3.151708e+03,train_penalty: 1.036941e+00,
# Epoch 17, batch 4/13,train_objective: 3.134587e+03,train_penalty: 1.031945e+00,
# Epoch 17, batch 5/13,train_objective: 3.139896e+03,train_penalty: 1.026480e+00,
# Epoch 17, batch 6/13,train_objective: 3.127411e+03,train_penalty: 1.020942e+00,
# Epoch 17, batch 7/13,train_objective: 3.127070e+03,train_penalty: 1.015435e+00,
# Epoch 17, batch 8/13,train_objective: 3.116981e+03,train_penalty: 1.009948e+00,
# Epoch 17, batch 9/13,train_objective: 3.112375e+03,train_penalty: 1.004812e+00,
# Epoch 17, batch 10/13,train_objective: 3.104234e+03,train_penalty: 9.996359e-01,
# Epoch 17, batch 10/13,train_objective: 3.104234e+03,train_penalty: 9.996359e-01,val_objective: 9.446382e+03,val_penalty: 1.004381e+00
# Epoch 17, batch 11/13,train_objective: 6.159542e+03,train_penalty: 1.940340e+00,
# Epoch 17, batch 12/13,train_objective: 4.587365e+03,train_penalty: 1.435622e+00,
# Epoch 17, batch 13/13,train_objective: 4.070336e+03,train_penalty: 1.264165e+00,
# Epoch 18, batch 1/13,train_objective: 3.002798e+03,train_penalty: 9.122138e-01,
# Epoch 18, batch 2/13,train_objective: 3.009592e+03,train_penalty: 9.076253e-01,
# Epoch 18, batch 3/13,train_objective: 3.010542e+03,train_penalty: 9.037389e-01,
# Epoch 18, batch 4/13,train_objective: 3.032605e+03,train_penalty: 8.989993e-01,
# Epoch 18, batch 5/13,train_objective: 3.077708e+03,train_penalty: 8.950565e-01,
# Epoch 18, batch 6/13,train_objective: 3.180440e+03,train_penalty: 8.907115e-01,
# Epoch 18, batch 7/13,train_objective: 3.248051e+03,train_penalty: 8.867093e-01,
# Epoch 18, batch 8/13,train_objective: 3.247288e+03,train_penalty: 8.825230e-01,
# Epoch 18, batch 9/13,train_objective: 3.229648e+03,train_penalty: 8.784154e-01,
# Epoch 18, batch 10/13,train_objective: 3.239077e+03,train_penalty: 8.741895e-01,
# Epoch 18, batch 10/13,train_objective: 3.239077e+03,train_penalty: 8.741895e-01,val_objective: 6.212006e+03,val_penalty: 8.631762e-01
# Epoch 18, batch 11/13,train_objective: 6.312790e+03,train_penalty: 1.702312e+00,
# Epoch 18, batch 12/13,train_objective: 4.734371e+03,train_penalty: 1.260733e+00,
# Epoch 18, batch 13/13,train_objective: 4.195523e+03,train_penalty: 1.111115e+00,
# Epoch 19, batch 1/13,train_objective: 3.051702e+03,train_penalty: 8.069550e-01,
# Epoch 19, batch 2/13,train_objective: 3.079754e+03,train_penalty: 8.039819e-01,
# Epoch 19, batch 3/13,train_objective: 3.049634e+03,train_penalty: 7.994150e-01,
# Epoch 19, batch 4/13,train_objective: 3.052595e+03,train_penalty: 7.956400e-01,
# Epoch 19, batch 5/13,train_objective: 3.036348e+03,train_penalty: 7.915896e-01,
# Epoch 19, batch 6/13,train_objective: 3.031107e+03,train_penalty: 7.878730e-01,
# Epoch 19, batch 7/13,train_objective: 3.022040e+03,train_penalty: 7.837992e-01,
# Epoch 19, batch 8/13,train_objective: 3.012193e+03,train_penalty: 7.799521e-01,
# Epoch 19, batch 9/13,train_objective: 3.007169e+03,train_penalty: 7.760717e-01,
# Epoch 19, batch 10/13,train_objective: 2.997816e+03,train_penalty: 7.720539e-01,
# Epoch 19, batch 10/13,train_objective: 2.997816e+03,train_penalty: 7.720539e-01,val_objective: 7.576346e+03,val_penalty: 7.428632e-01
# Epoch 19, batch 11/13,train_objective: 5.946737e+03,train_penalty: 1.501102e+00,
# Epoch 19, batch 12/13,train_objective: 4.419253e+03,train_penalty: 1.110627e+00,
# Epoch 19, batch 13/13,train_objective: 3.918223e+03,train_penalty: 9.774897e-01,
# Epoch 20, batch 1/13,train_objective: 2.883686e+03,train_penalty: 7.023412e-01,
# Epoch 20, batch 2/13,train_objective: 2.890100e+03,train_penalty: 6.985146e-01,
# Epoch 20, batch 3/13,train_objective: 2.882033e+03,train_penalty: 6.937204e-01,
# Epoch 20, batch 4/13,train_objective: 2.877233e+03,train_penalty: 6.893267e-01,
# Epoch 20, batch 5/13,train_objective: 2.872552e+03,train_penalty: 6.853068e-01,
# Epoch 20, batch 6/13,train_objective: 2.866922e+03,train_penalty: 6.815710e-01,
# Epoch 20, batch 7/13,train_objective: 2.863378e+03,train_penalty: 6.775467e-01,
# Epoch 20, batch 8/13,train_objective: 2.858495e+03,train_penalty: 6.734515e-01,
# Epoch 20, batch 9/13,train_objective: 2.854439e+03,train_penalty: 6.692706e-01,
# Epoch 20, batch 10/13,train_objective: 2.850109e+03,train_penalty: 6.654763e-01,
# Epoch 20, batch 10/13,train_objective: 2.850109e+03,train_penalty: 6.654763e-01,val_objective: 7.832961e+03,val_penalty: 7.078336e-01
# Epoch 20, batch 11/13,train_objective: 5.657861e+03,train_penalty: 1.284679e+00,
# Epoch 20, batch 12/13,train_objective: 4.231827e+03,train_penalty: 9.488606e-01,
# Epoch 20, batch 13/13,train_objective: 3.755165e+03,train_penalty: 8.348319e-01,
# Epoch 21, batch 1/13,train_objective: 2.789593e+03,train_penalty: 5.973440e-01,
# Epoch 21, batch 2/13,train_objective: 2.789055e+03,train_penalty: 5.939824e-01,
# Epoch 21, batch 3/13,train_objective: 2.785168e+03,train_penalty: 5.903450e-01,
# Epoch 21, batch 4/13,train_objective: 2.782064e+03,train_penalty: 5.867742e-01,
# Epoch 21, batch 5/13,train_objective: 2.779919e+03,train_penalty: 5.824961e-01,
# Epoch 21, batch 6/13,train_objective: 2.778307e+03,train_penalty: 5.790166e-01,
# Epoch 21, batch 7/13,train_objective: 2.774775e+03,train_penalty: 5.750705e-01,
# Epoch 21, batch 8/13,train_objective: 2.772926e+03,train_penalty: 5.711145e-01,
# Epoch 21, batch 9/13,train_objective: 2.771896e+03,train_penalty: 5.674462e-01,
# Epoch 21, batch 10/13,train_objective: 2.772275e+03,train_penalty: 5.639724e-01,
# Epoch 21, batch 10/13,train_objective: 2.772275e+03,train_penalty: 5.639724e-01,val_objective: 7.212075e+03,val_penalty: 5.375527e-01
# Epoch 21, batch 11/13,train_objective: 5.583586e+03,train_penalty: 1.088408e+00,
# Epoch 21, batch 12/13,train_objective: 4.225602e+03,train_penalty: 8.030315e-01,
# Epoch 21, batch 13/13,train_objective: 3.785432e+03,train_penalty: 7.048559e-01,
# Epoch 22, batch 1/13,train_objective: 2.798349e+03,train_penalty: 5.022318e-01,
# Epoch 22, batch 2/13,train_objective: 2.761083e+03,train_penalty: 4.991516e-01,
# Epoch 22, batch 3/13,train_objective: 2.768143e+03,train_penalty: 4.961968e-01,
# Epoch 22, batch 4/13,train_objective: 2.765195e+03,train_penalty: 4.925243e-01,
# Epoch 22, batch 5/13,train_objective: 2.754189e+03,train_penalty: 4.891166e-01,
# Epoch 22, batch 6/13,train_objective: 2.752373e+03,train_penalty: 4.857394e-01,
# Epoch 22, batch 7/13,train_objective: 2.747140e+03,train_penalty: 4.822693e-01,
# Epoch 22, batch 8/13,train_objective: 2.741099e+03,train_penalty: 4.787375e-01,
# Epoch 22, batch 9/13,train_objective: 2.738962e+03,train_penalty: 4.751935e-01,
# Epoch 22, batch 10/13,train_objective: 2.733250e+03,train_penalty: 4.715700e-01,
# Epoch 22, batch 10/13,train_objective: 2.733250e+03,train_penalty: 4.715700e-01,val_objective: 6.321133e+03,val_penalty: 4.316870e-01
# Epoch 22, batch 11/13,train_objective: 5.424827e+03,train_penalty: 9.038674e-01,
# Epoch 22, batch 12/13,train_objective: 4.057713e+03,train_penalty: 6.650693e-01,
# Epoch 22, batch 13/13,train_objective: 3.594785e+03,train_penalty: 5.829531e-01,
# Epoch 23, batch 1/13,train_objective: 2.684691e+03,train_penalty: 4.125031e-01,
# Epoch 23, batch 2/13,train_objective: 2.678130e+03,train_penalty: 4.090876e-01,
# Epoch 23, batch 3/13,train_objective: 2.676821e+03,train_penalty: 4.054408e-01,
# Epoch 23, batch 4/13,train_objective: 2.683057e+03,train_penalty: 4.023741e-01,
# Epoch 23, batch 5/13,train_objective: 2.690838e+03,train_penalty: 3.993120e-01,
# Epoch 23, batch 6/13,train_objective: 2.707910e+03,train_penalty: 3.959665e-01,
# Epoch 23, batch 7/13,train_objective: 2.735851e+03,train_penalty: 3.929076e-01,
# Epoch 23, batch 8/13,train_objective: 2.746107e+03,train_penalty: 3.898946e-01,
# Epoch 23, batch 9/13,train_objective: 2.742942e+03,train_penalty: 3.866166e-01,
# Epoch 23, batch 10/13,train_objective: 2.732408e+03,train_penalty: 3.834098e-01,
# Epoch 23, batch 10/13,train_objective: 2.732408e+03,train_penalty: 3.834098e-01,val_objective: 5.415870e+03,val_penalty: 3.621523e-01
# Epoch 23, batch 11/13,train_objective: 5.446720e+03,train_penalty: 7.339907e-01,
# Epoch 23, batch 12/13,train_objective: 4.089651e+03,train_penalty: 5.389832e-01,
# Epoch 23, batch 13/13,train_objective: 3.605849e+03,train_penalty: 4.712662e-01,
# Epoch 24, batch 1/13,train_objective: 2.665317e+03,train_penalty: 3.327118e-01,
# Epoch 24, batch 2/13,train_objective: 2.669318e+03,train_penalty: 3.294213e-01,
# Epoch 24, batch 3/13,train_objective: 2.661676e+03,train_penalty: 3.264176e-01,
# Epoch 24, batch 4/13,train_objective: 2.655753e+03,train_penalty: 3.234948e-01,
# Epoch 24, batch 5/13,train_objective: 2.650915e+03,train_penalty: 3.206797e-01,
# Epoch 24, batch 6/13,train_objective: 2.645785e+03,train_penalty: 3.176252e-01,
# Epoch 24, batch 7/13,train_objective: 2.641068e+03,train_penalty: 3.146577e-01,
# Epoch 24, batch 8/13,train_objective: 2.637733e+03,train_penalty: 3.117451e-01,
# Epoch 24, batch 9/13,train_objective: 2.632947e+03,train_penalty: 3.088475e-01,
# Epoch 24, batch 10/13,train_objective: 2.629731e+03,train_penalty: 3.059300e-01,
# Epoch 24, batch 10/13,train_objective: 2.629731e+03,train_penalty: 3.059300e-01,val_objective: 5.425626e+03,val_penalty: 3.166221e-01
# Epoch 24, batch 11/13,train_objective: 5.232199e+03,train_penalty: 5.825652e-01,
# Epoch 24, batch 12/13,train_objective: 3.903534e+03,train_penalty: 4.251837e-01,
# Epoch 24, batch 13/13,train_objective: 3.462528e+03,train_penalty: 3.710501e-01,
# Epoch 25, batch 1/13,train_objective: 2.581342e+03,train_penalty: 2.581009e-01,
# Epoch 25, batch 2/13,train_objective: 2.570059e+03,train_penalty: 2.553403e-01,
# Epoch 25, batch 3/13,train_objective: 2.566436e+03,train_penalty: 2.526419e-01,
# Epoch 25, batch 4/13,train_objective: 2.566968e+03,train_penalty: 2.502736e-01,
# Epoch 25, batch 5/13,train_objective: 2.562690e+03,train_penalty: 2.476721e-01,
# Epoch 25, batch 6/13,train_objective: 2.559833e+03,train_penalty: 2.452318e-01,
# Epoch 25, batch 7/13,train_objective: 2.558477e+03,train_penalty: 2.428290e-01,
# Epoch 25, batch 8/13,train_objective: 2.555421e+03,train_penalty: 2.404811e-01,
# Epoch 25, batch 9/13,train_objective: 2.553085e+03,train_penalty: 2.382644e-01,
# Epoch 25, batch 10/13,train_objective: 2.551567e+03,train_penalty: 2.359012e-01,
# Epoch 25, batch 10/13,train_objective: 2.551567e+03,train_penalty: 2.359012e-01,val_objective: 6.029804e+03,val_penalty: 2.662254e-01
# Epoch 25, batch 11/13,train_objective: 5.075626e+03,train_penalty: 4.463607e-01,
# Epoch 25, batch 12/13,train_objective: 3.797621e+03,train_penalty: 3.258671e-01,
# Epoch 25, batch 13/13,train_objective: 3.375799e+03,train_penalty: 2.848846e-01,
# Epoch 26, batch 1/13,train_objective: 2.527494e+03,train_penalty: 1.971087e-01,
# Epoch 26, batch 2/13,train_objective: 2.524625e+03,train_penalty: 1.955037e-01,
# Epoch 26, batch 3/13,train_objective: 2.529924e+03,train_penalty: 1.934010e-01,
# Epoch 26, batch 4/13,train_objective: 2.551419e+03,train_penalty: 1.913216e-01,
# Epoch 26, batch 5/13,train_objective: 2.603522e+03,train_penalty: 1.896118e-01,
# Epoch 26, batch 6/13,train_objective: 2.687464e+03,train_penalty: 1.876281e-01,
# Epoch 26, batch 7/13,train_objective: 2.720486e+03,train_penalty: 1.855474e-01,
# Epoch 26, batch 8/13,train_objective: 2.713272e+03,train_penalty: 1.837789e-01,
# Epoch 26, batch 9/13,train_objective: 2.712825e+03,train_penalty: 1.819625e-01,
# Epoch 26, batch 10/13,train_objective: 2.708017e+03,train_penalty: 1.800850e-01,
# Epoch 26, batch 10/13,train_objective: 2.708017e+03,train_penalty: 1.800850e-01,val_objective: 4.203800e+03,val_penalty: 1.920979e-01
# Epoch 26, batch 11/13,train_objective: 5.405215e+03,train_penalty: 3.406091e-01,
# Epoch 26, batch 12/13,train_objective: 3.989320e+03,train_penalty: 2.491215e-01,
# Epoch 26, batch 13/13,train_objective: 3.548793e+03,train_penalty: 2.172480e-01,
# Epoch 27, batch 1/13,train_objective: 2.554830e+03,train_penalty: 1.516036e-01,
# Epoch 27, batch 2/13,train_objective: 2.579464e+03,train_penalty: 1.495817e-01,
# Epoch 27, batch 3/13,train_objective: 2.568058e+03,train_penalty: 1.482603e-01,
# Epoch 27, batch 4/13,train_objective: 2.569383e+03,train_penalty: 1.466328e-01,
# Epoch 27, batch 5/13,train_objective: 2.562660e+03,train_penalty: 1.449407e-01,
# Epoch 27, batch 6/13,train_objective: 2.557569e+03,train_penalty: 1.433445e-01,
# Epoch 27, batch 7/13,train_objective: 2.553723e+03,train_penalty: 1.418471e-01,
# Epoch 27, batch 8/13,train_objective: 2.548765e+03,train_penalty: 1.403031e-01,
# Epoch 27, batch 9/13,train_objective: 2.544692e+03,train_penalty: 1.389837e-01,
# Epoch 27, batch 10/13,train_objective: 2.539345e+03,train_penalty: 1.376622e-01,
# Epoch 27, batch 10/13,train_objective: 2.539345e+03,train_penalty: 1.376622e-01,val_objective: 4.660755e+03,val_penalty: 1.481984e-01
# Epoch 27, batch 11/13,train_objective: 5.027830e+03,train_penalty: 2.599460e-01,
# Epoch 27, batch 12/13,train_objective: 3.752407e+03,train_penalty: 1.897330e-01,
# Epoch 27, batch 13/13,train_objective: 3.327372e+03,train_penalty: 1.655300e-01,
# Epoch 28, batch 1/13,train_objective: 2.462558e+03,train_penalty: 1.143258e-01,
# Epoch 28, batch 2/13,train_objective: 2.463260e+03,train_penalty: 1.143237e-01,
# Epoch 28, batch 3/13,train_objective: 2.459662e+03,train_penalty: 1.129668e-01,
# Epoch 28, batch 4/13,train_objective: 2.456780e+03,train_penalty: 1.117119e-01,
# Epoch 28, batch 5/13,train_objective: 2.454659e+03,train_penalty: 1.104342e-01,
# Epoch 28, batch 6/13,train_objective: 2.452501e+03,train_penalty: 1.092285e-01,
# Epoch 28, batch 7/13,train_objective: 2.449278e+03,train_penalty: 1.079391e-01,
# Epoch 28, batch 8/13,train_objective: 2.446966e+03,train_penalty: 1.067554e-01,
# Epoch 28, batch 9/13,train_objective: 2.444137e+03,train_penalty: 1.057340e-01,
# Epoch 28, batch 10/13,train_objective: 2.441907e+03,train_penalty: 1.047461e-01,
# Epoch 28, batch 10/13,train_objective: 2.441907e+03,train_penalty: 1.047461e-01,val_objective: 5.419382e+03,val_penalty: 1.499533e-01
# Epoch 28, batch 11/13,train_objective: 4.858237e+03,train_penalty: 1.991777e-01,
# Epoch 28, batch 12/13,train_objective: 3.634584e+03,train_penalty: 1.452358e-01,
# Epoch 28, batch 13/13,train_objective: 3.224949e+03,train_penalty: 1.265377e-01,
# Epoch 29, batch 1/13,train_objective: 2.405129e+03,train_penalty: 8.710234e-02,
# Epoch 29, batch 2/13,train_objective: 2.402061e+03,train_penalty: 8.707076e-02,
# Epoch 29, batch 3/13,train_objective: 2.398751e+03,train_penalty: 8.605845e-02,
# Epoch 29, batch 4/13,train_objective: 2.396769e+03,train_penalty: 8.518548e-02,
# Epoch 29, batch 5/13,train_objective: 2.396425e+03,train_penalty: 8.476279e-02,
# Epoch 29, batch 6/13,train_objective: 2.394672e+03,train_penalty: 8.390843e-02,
# Epoch 29, batch 7/13,train_objective: 2.392243e+03,train_penalty: 8.301426e-02,
# Epoch 29, batch 8/13,train_objective: 2.390753e+03,train_penalty: 8.224829e-02,
# Epoch 29, batch 9/13,train_objective: 2.388478e+03,train_penalty: 8.158753e-02,
# Epoch 29, batch 10/13,train_objective: 2.386297e+03,train_penalty: 8.081206e-02,
# Epoch 29, batch 10/13,train_objective: 2.386297e+03,train_penalty: 8.081206e-02,val_objective: 4.985798e+03,val_penalty: 1.239980e-01
# Epoch 29, batch 11/13,train_objective: 4.750615e+03,train_penalty: 1.533954e-01,
# Epoch 29, batch 12/13,train_objective: 3.555293e+03,train_penalty: 1.126730e-01,
# Epoch 29, batch 13/13,train_objective: 3.159000e+03,train_penalty: 9.855584e-02,
# Epoch 30, batch 1/13,train_objective: 2.363247e+03,train_penalty: 6.885110e-02,
# Epoch 30, batch 2/13,train_objective: 2.361967e+03,train_penalty: 6.771709e-02,
# Epoch 30, batch 3/13,train_objective: 2.362998e+03,train_penalty: 6.719833e-02,
# Epoch 30, batch 4/13,train_objective: 2.363397e+03,train_penalty: 6.650664e-02,
# Epoch 30, batch 5/13,train_objective: 2.365945e+03,train_penalty: 6.576266e-02,
# Epoch 30, batch 6/13,train_objective: 2.371026e+03,train_penalty: 6.521720e-02,
# Epoch 30, batch 7/13,train_objective: 2.380138e+03,train_penalty: 6.473956e-02,
# Epoch 30, batch 8/13,train_objective: 2.396732e+03,train_penalty: 6.426108e-02,
# Epoch 30, batch 9/13,train_objective: 2.419040e+03,train_penalty: 6.368286e-02,
# Epoch 30, batch 10/13,train_objective: 2.442790e+03,train_penalty: 6.316120e-02,
# Epoch 30, batch 10/13,train_objective: 2.442790e+03,train_penalty: 6.316120e-02,val_objective: 3.731552e+03,val_penalty: 9.793409e-02
# Epoch 30, batch 11/13,train_objective: 5.017270e+03,train_penalty: 1.213626e-01,
# Epoch 30, batch 12/13,train_objective: 3.800250e+03,train_penalty: 8.944156e-02,
# Epoch 30, batch 13/13,train_objective: 3.407014e+03,train_penalty: 7.803039e-02,
# Epoch 31, batch 1/13,train_objective: 2.519019e+03,train_penalty: 5.424069e-02,
# Epoch 31, batch 2/13,train_objective: 2.445406e+03,train_penalty: 5.459886e-02,
# Epoch 31, batch 3/13,train_objective: 2.458924e+03,train_penalty: 5.472154e-02,
# Epoch 31, batch 4/13,train_objective: 2.465028e+03,train_penalty: 5.452036e-02,
# Epoch 31, batch 5/13,train_objective: 2.441751e+03,train_penalty: 5.402505e-02,
# Epoch 31, batch 6/13,train_objective: 2.440109e+03,train_penalty: 5.362658e-02,
# Epoch 31, batch 7/13,train_objective: 2.433876e+03,train_penalty: 5.340617e-02,
# Epoch 31, batch 8/13,train_objective: 2.424284e+03,train_penalty: 5.325294e-02,
# Epoch 31, batch 9/13,train_objective: 2.420589e+03,train_penalty: 5.296488e-02,
# Epoch 31, batch 10/13,train_objective: 2.413087e+03,train_penalty: 5.263071e-02,
# Epoch 31, batch 10/13,train_objective: 2.413087e+03,train_penalty: 5.263071e-02,val_objective: 3.329362e+03,val_penalty: 8.227208e-02
# Epoch 31, batch 11/13,train_objective: 4.774710e+03,train_penalty: 1.013520e-01,
# Epoch 31, batch 12/13,train_objective: 3.558588e+03,train_penalty: 7.548276e-02,
# Epoch 31, batch 13/13,train_objective: 3.151598e+03,train_penalty: 6.616380e-02,
# Epoch 32, batch 1/13,train_objective: 2.342221e+03,train_penalty: 4.831452e-02,
# Epoch 32, batch 2/13,train_objective: 2.329553e+03,train_penalty: 4.823216e-02,
# Epoch 32, batch 3/13,train_objective: 2.332421e+03,train_penalty: 4.778503e-02,
# Epoch 32, batch 4/13,train_objective: 2.325399e+03,train_penalty: 4.746553e-02,
# Epoch 32, batch 5/13,train_objective: 2.322035e+03,train_penalty: 4.731909e-02,
# Epoch 32, batch 6/13,train_objective: 2.322335e+03,train_penalty: 4.727177e-02,
# Epoch 32, batch 7/13,train_objective: 2.316409e+03,train_penalty: 4.711134e-02,
# Epoch 32, batch 8/13,train_objective: 2.315522e+03,train_penalty: 4.690851e-02,
# Epoch 32, batch 9/13,train_objective: 2.312826e+03,train_penalty: 4.674509e-02,
# Epoch 32, batch 10/13,train_objective: 2.309120e+03,train_penalty: 4.661124e-02,
# Epoch 32, batch 10/13,train_objective: 2.309120e+03,train_penalty: 4.661124e-02,val_objective: 4.179048e+03,val_penalty: 1.022134e-01
# Epoch 32, batch 11/13,train_objective: 4.601093e+03,train_penalty: 9.045756e-02,
# Epoch 32, batch 12/13,train_objective: 3.436597e+03,train_penalty: 6.741838e-02,
# Epoch 32, batch 13/13,train_objective: 3.049294e+03,train_penalty: 6.008513e-02,
# Epoch 33, batch 1/13,train_objective: 2.274301e+03,train_penalty: 4.452258e-02,
# Epoch 33, batch 2/13,train_objective: 2.265941e+03,train_penalty: 4.402505e-02,
# Epoch 33, batch 3/13,train_objective: 2.263665e+03,train_penalty: 4.400538e-02,
# Epoch 33, batch 4/13,train_objective: 2.262792e+03,train_penalty: 4.371913e-02,
# Epoch 33, batch 5/13,train_objective: 2.259712e+03,train_penalty: 4.338139e-02,
# Epoch 33, batch 6/13,train_objective: 2.257495e+03,train_penalty: 4.312669e-02,
# Epoch 33, batch 7/13,train_objective: 2.255390e+03,train_penalty: 4.301569e-02,
# Epoch 33, batch 8/13,train_objective: 2.253329e+03,train_penalty: 4.277942e-02,
# Epoch 33, batch 9/13,train_objective: 2.251164e+03,train_penalty: 4.256999e-02,
# Epoch 33, batch 10/13,train_objective: 2.249483e+03,train_penalty: 4.241500e-02,
# Epoch 33, batch 10/13,train_objective: 2.249483e+03,train_penalty: 4.241500e-02,val_objective: 4.048269e+03,val_penalty: 7.211047e-02
# Epoch 33, batch 11/13,train_objective: 4.475908e+03,train_penalty: 8.311769e-02,
# Epoch 33, batch 12/13,train_objective: 3.348706e+03,train_penalty: 6.144824e-02,
# Epoch 33, batch 13/13,train_objective: 2.973169e+03,train_penalty: 5.388257e-02,
# Epoch 34, batch 1/13,train_objective: 2.223017e+03,train_penalty: 3.958050e-02,
# Epoch 34, batch 2/13,train_objective: 2.218439e+03,train_penalty: 3.872790e-02,
# Epoch 34, batch 3/13,train_objective: 2.215089e+03,train_penalty: 3.831433e-02,
# Epoch 34, batch 4/13,train_objective: 2.213192e+03,train_penalty: 3.815693e-02,
# Epoch 34, batch 5/13,train_objective: 2.212626e+03,train_penalty: 3.817236e-02,
# Epoch 34, batch 6/13,train_objective: 2.211481e+03,train_penalty: 3.814457e-02,
# Epoch 34, batch 7/13,train_objective: 2.209757e+03,train_penalty: 3.796631e-02,
# Epoch 34, batch 8/13,train_objective: 2.207904e+03,train_penalty: 3.765224e-02,
# Epoch 34, batch 9/13,train_objective: 2.207583e+03,train_penalty: 3.744186e-02,
# Epoch 34, batch 10/13,train_objective: 2.208526e+03,train_penalty: 3.732012e-02,
# Epoch 34, batch 10/13,train_objective: 2.208526e+03,train_penalty: 3.732012e-02,val_objective: 3.870174e+03,val_penalty: 8.035758e-02
# Epoch 34, batch 11/13,train_objective: 4.432821e+03,train_penalty: 7.249036e-02,
# Epoch 34, batch 12/13,train_objective: 3.333982e+03,train_penalty: 5.395616e-02,
# Epoch 34, batch 13/13,train_objective: 2.974582e+03,train_penalty: 4.752844e-02,
# Epoch 35, batch 1/13,train_objective: 2.292146e+03,train_penalty: 3.491985e-02,
# Epoch 35, batch 2/13,train_objective: 2.301522e+03,train_penalty: 3.472406e-02,
# Epoch 35, batch 3/13,train_objective: 2.301374e+03,train_penalty: 3.441446e-02,
# Epoch 35, batch 4/13,train_objective: 2.296585e+03,train_penalty: 3.414000e-02,
# Epoch 35, batch 5/13,train_objective: 2.302272e+03,train_penalty: 3.402762e-02,
# Epoch 35, batch 6/13,train_objective: 2.305131e+03,train_penalty: 3.392779e-02,
# Epoch 35, batch 7/13,train_objective: 2.291079e+03,train_penalty: 3.372517e-02,
# Epoch 35, batch 8/13,train_objective: 2.284580e+03,train_penalty: 3.357855e-02,
# Epoch 35, batch 9/13,train_objective: 2.280421e+03,train_penalty: 3.345551e-02,
# Epoch 35, batch 10/13,train_objective: 2.272049e+03,train_penalty: 3.334396e-02,
# Epoch 35, batch 10/13,train_objective: 2.272049e+03,train_penalty: 3.334396e-02,val_objective: 2.594736e+03,val_penalty: 5.234119e-02
# Epoch 35, batch 11/13,train_objective: 4.498221e+03,train_penalty: 6.544310e-02,
# Epoch 35, batch 12/13,train_objective: 3.348553e+03,train_penalty: 4.905658e-02,
# Epoch 35, batch 13/13,train_objective: 2.962099e+03,train_penalty: 4.344801e-02,
# Epoch 36, batch 1/13,train_objective: 2.200478e+03,train_penalty: 3.193693e-02,
# Epoch 36, batch 2/13,train_objective: 2.185290e+03,train_penalty: 3.188269e-02,
# Epoch 36, batch 3/13,train_objective: 2.182974e+03,train_penalty: 3.173257e-02,
# Epoch 36, batch 4/13,train_objective: 2.179928e+03,train_penalty: 3.172435e-02,
# Epoch 36, batch 5/13,train_objective: 2.177558e+03,train_penalty: 3.175179e-02,
# Epoch 36, batch 6/13,train_objective: 2.176331e+03,train_penalty: 3.173609e-02,
# Epoch 36, batch 7/13,train_objective: 2.171956e+03,train_penalty: 3.171699e-02,
# Epoch 36, batch 8/13,train_objective: 2.169892e+03,train_penalty: 3.167213e-02,
# Epoch 36, batch 9/13,train_objective: 2.167963e+03,train_penalty: 3.160275e-02,
# Epoch 36, batch 10/13,train_objective: 2.164935e+03,train_penalty: 3.148743e-02,
# Epoch 36, batch 10/13,train_objective: 2.164935e+03,train_penalty: 3.148743e-02,val_objective: 3.223313e+03,val_penalty: 3.197640e-02
# Epoch 36, batch 11/13,train_objective: 4.310161e+03,train_penalty: 6.192402e-02,
# Epoch 36, batch 12/13,train_objective: 3.223941e+03,train_penalty: 4.583977e-02,
# Epoch 36, batch 13/13,train_objective: 2.863059e+03,train_penalty: 4.039671e-02,
# Epoch 37, batch 1/13,train_objective: 2.141779e+03,train_penalty: 2.962207e-02,
# Epoch 37, batch 2/13,train_objective: 2.144984e+03,train_penalty: 2.974906e-02,
# Epoch 37, batch 3/13,train_objective: 2.149465e+03,train_penalty: 2.944823e-02,
# Epoch 37, batch 4/13,train_objective: 2.156829e+03,train_penalty: 2.922450e-02,
# Epoch 37, batch 5/13,train_objective: 2.169065e+03,train_penalty: 2.913432e-02,
# ...
# Epoch 86, batch 8/13,train_objective: 1.480323e+03,train_penalty: 2.806490e-03,
# Epoch 86, batch 9/13,train_objective: 1.488758e+03,train_penalty: 2.799214e-03,
# Epoch 86, batch 10/13,train_objective: 1.492453e+03,train_penalty: 2.800255e-03,
# Epoch 86, batch 10/13,train_objective: 1.492453e+03,train_penalty: 2.800255e-03,val_objective: 1.536586e+03,val_penalty: 1.136578e-02
# Epoch 86, batch 11/13,train_objective: 2.948978e+03,train_penalty: 5.506567e-03,
# Epoch 86, batch 12/13,train_objective: 2.214308e+03,train_penalty: 4.154902e-03,
# Epoch 86, batch 13/13,train_objective: 1.980933e+03,train_penalty: 3.679377e-03,
# Epoch 87, batch 1/13,train_objective: 1.483652e+03,train_penalty: 2.783997e-03,
# Epoch 87, batch 2/13,train_objective: 1.459933e+03,train_penalty: 2.805802e-03,
# Epoch 87, batch 3/13,train_objective: 1.453583e+03,train_penalty: 2.802228e-03,
# Epoch 87, batch 4/13,train_objective: 1.452180e+03,train_penalty: 2.810691e-03,
# Epoch 87, batch 5/13,train_objective: 1.448632e+03,train_penalty: 2.821997e-03,
# Epoch 87, batch 6/13,train_objective: 1.445066e+03,train_penalty: 2.825167e-03,
# Epoch 87, batch 7/13,train_objective: 1.441870e+03,train_penalty: 2.823565e-03,
# Epoch 87, batch 8/13,train_objective: 1.438960e+03,train_penalty: 2.827821e-03,
# Epoch 87, batch 9/13,train_objective: 1.436405e+03,train_penalty: 2.827245e-03,
# Epoch 87, batch 10/13,train_objective: 1.435146e+03,train_penalty: 2.826438e-03,
# Epoch 87, batch 10/13,train_objective: 1.435146e+03,train_penalty: 2.826438e-03,val_objective: 1.510835e+03,val_penalty: 1.027178e-02
# Epoch 87, batch 11/13,train_objective: 2.847117e+03,train_penalty: 5.656001e-03,
# Epoch 87, batch 12/13,train_objective: 2.128475e+03,train_penalty: 4.232876e-03,
# Epoch 87, batch 13/13,train_objective: 1.891160e+03,train_penalty: 3.763840e-03,
# Epoch 88, batch 1/13,train_objective: 1.402780e+03,train_penalty: 2.874763e-03,
# Epoch 88, batch 2/13,train_objective: 1.402444e+03,train_penalty: 2.858400e-03,
# Epoch 88, batch 3/13,train_objective: 1.404273e+03,train_penalty: 2.859531e-03,
# Epoch 88, batch 4/13,train_objective: 1.402707e+03,train_penalty: 2.842327e-03,
# Epoch 88, batch 5/13,train_objective: 1.402769e+03,train_penalty: 2.824012e-03,
# Epoch 88, batch 6/13,train_objective: 1.402257e+03,train_penalty: 2.828577e-03,
# Epoch 88, batch 7/13,train_objective: 1.401159e+03,train_penalty: 2.824443e-03,
# Epoch 88, batch 8/13,train_objective: 1.400500e+03,train_penalty: 2.819583e-03,
# Epoch 88, batch 9/13,train_objective: 1.399706e+03,train_penalty: 2.811955e-03,
# Epoch 88, batch 10/13,train_objective: 1.399174e+03,train_penalty: 2.810986e-03,
# Epoch 88, batch 10/13,train_objective: 1.399174e+03,train_penalty: 2.810986e-03,val_objective: 1.620827e+03,val_penalty: 3.010787e-03
# Epoch 88, batch 11/13,train_objective: 2.785858e+03,train_penalty: 5.518899e-03,
# Epoch 88, batch 12/13,train_objective: 2.089424e+03,train_penalty: 4.116523e-03,
# Epoch 88, batch 13/13,train_objective: 1.858486e+03,train_penalty: 3.653907e-03,
# Epoch 89, batch 1/13,train_objective: 1.392223e+03,train_penalty: 2.683575e-03,
# Epoch 89, batch 2/13,train_objective: 1.389855e+03,train_penalty: 2.724609e-03,
# Epoch 89, batch 3/13,train_objective: 1.390815e+03,train_penalty: 2.725895e-03,
# Epoch 89, batch 4/13,train_objective: 1.390016e+03,train_penalty: 2.713129e-03,
# Epoch 89, batch 5/13,train_objective: 1.388932e+03,train_penalty: 2.717555e-03,
# Epoch 89, batch 6/13,train_objective: 1.390594e+03,train_penalty: 2.724884e-03,
# Epoch 89, batch 7/13,train_objective: 1.393145e+03,train_penalty: 2.722389e-03,
# Epoch 89, batch 8/13,train_objective: 1.394825e+03,train_penalty: 2.721390e-03,
# Epoch 89, batch 9/13,train_objective: 1.397761e+03,train_penalty: 2.717266e-03,
# Epoch 89, batch 10/13,train_objective: 1.401434e+03,train_penalty: 2.715686e-03,
# Epoch 89, batch 10/13,train_objective: 1.401434e+03,train_penalty: 2.715686e-03,val_objective: 1.600649e+03,val_penalty: 1.595279e-02
# Epoch 89, batch 11/13,train_objective: 2.831396e+03,train_penalty: 5.450136e-03,
# Epoch 89, batch 12/13,train_objective: 2.130332e+03,train_penalty: 4.100954e-03,
# Epoch 89, batch 13/13,train_objective: 1.894004e+03,train_penalty: 3.644878e-03,
# Epoch 90, batch 1/13,train_objective: 1.405420e+03,train_penalty: 2.695881e-03,
# Epoch 90, batch 2/13,train_objective: 1.404683e+03,train_penalty: 2.676956e-03,
# Epoch 90, batch 3/13,train_objective: 1.402886e+03,train_penalty: 2.672875e-03,
# Epoch 90, batch 4/13,train_objective: 1.403076e+03,train_penalty: 2.674265e-03,
# Epoch 90, batch 5/13,train_objective: 1.402144e+03,train_penalty: 2.671873e-03,
# Epoch 90, batch 6/13,train_objective: 1.401398e+03,train_penalty: 2.666849e-03,
# Epoch 90, batch 7/13,train_objective: 1.399560e+03,train_penalty: 2.650495e-03,
# Epoch 90, batch 8/13,train_objective: 1.397527e+03,train_penalty: 2.637925e-03,
# Epoch 90, batch 9/13,train_objective: 1.396101e+03,train_penalty: 2.629609e-03,
# Epoch 90, batch 10/13,train_objective: 1.396052e+03,train_penalty: 2.627583e-03,
# Epoch 90, batch 10/13,train_objective: 1.396052e+03,train_penalty: 2.627583e-03,val_objective: 1.494706e+03,val_penalty: 3.436710e-03
# Epoch 90, batch 11/13,train_objective: 2.785382e+03,train_penalty: 5.127998e-03,
# Epoch 90, batch 12/13,train_objective: 2.083219e+03,train_penalty: 3.872048e-03,
# Epoch 90, batch 13/13,train_objective: 1.851392e+03,train_penalty: 3.456875e-03,
# Epoch 91, batch 1/13,train_objective: 1.388193e+03,train_penalty: 2.601842e-03,
# Epoch 91, batch 2/13,train_objective: 1.384548e+03,train_penalty: 2.549775e-03,
# Epoch 91, batch 3/13,train_objective: 1.382993e+03,train_penalty: 2.534506e-03,
# Epoch 91, batch 4/13,train_objective: 1.383049e+03,train_penalty: 2.525750e-03,
# Epoch 91, batch 5/13,train_objective: 1.383553e+03,train_penalty: 2.529805e-03,
# Epoch 91, batch 6/13,train_objective: 1.383867e+03,train_penalty: 2.516717e-03,
# Epoch 91, batch 7/13,train_objective: 1.384221e+03,train_penalty: 2.519645e-03,
# Epoch 91, batch 8/13,train_objective: 1.386481e+03,train_penalty: 2.524737e-03,
# Epoch 91, batch 9/13,train_objective: 1.389049e+03,train_penalty: 2.518347e-03,
# Epoch 91, batch 10/13,train_objective: 1.392114e+03,train_penalty: 2.515943e-03,
# Epoch 91, batch 10/13,train_objective: 1.392114e+03,train_penalty: 2.515943e-03,val_objective: 1.782460e+03,val_penalty: 2.681019e-03
# Epoch 91, batch 11/13,train_objective: 2.815180e+03,train_penalty: 5.023250e-03,
# Epoch 91, batch 12/13,train_objective: 2.118427e+03,train_penalty: 3.728590e-03,
# Epoch 91, batch 13/13,train_objective: 1.884284e+03,train_penalty: 3.320250e-03,
# Epoch 92, batch 1/13,train_objective: 1.413310e+03,train_penalty: 2.462057e-03,
# Epoch 92, batch 2/13,train_objective: 1.406389e+03,train_penalty: 2.463777e-03,
# Epoch 92, batch 3/13,train_objective: 1.404910e+03,train_penalty: 2.451370e-03,
# Epoch 92, batch 4/13,train_objective: 1.402265e+03,train_penalty: 2.454020e-03,
# Epoch 92, batch 5/13,train_objective: 1.400037e+03,train_penalty: 2.447133e-03,
# Epoch 92, batch 6/13,train_objective: 1.398256e+03,train_penalty: 2.449503e-03,
# Epoch 92, batch 7/13,train_objective: 1.397407e+03,train_penalty: 2.442739e-03,
# Epoch 92, batch 8/13,train_objective: 1.397174e+03,train_penalty: 2.438285e-03,
# Epoch 92, batch 9/13,train_objective: 1.395587e+03,train_penalty: 2.436675e-03,
# Epoch 92, batch 10/13,train_objective: 1.394178e+03,train_penalty: 2.440555e-03,
# Epoch 92, batch 10/13,train_objective: 1.394178e+03,train_penalty: 2.440555e-03,val_objective: 1.480215e+03,val_penalty: 2.227144e-02
# Epoch 92, batch 11/13,train_objective: 2.764433e+03,train_penalty: 4.823561e-03,
# Epoch 92, batch 12/13,train_objective: 2.074146e+03,train_penalty: 3.612193e-03,
# Epoch 92, batch 13/13,train_objective: 1.846199e+03,train_penalty: 3.209207e-03,
# Epoch 93, batch 1/13,train_objective: 1.387806e+03,train_penalty: 2.399025e-03,
# Epoch 93, batch 2/13,train_objective: 1.384816e+03,train_penalty: 2.399975e-03,
# Epoch 93, batch 3/13,train_objective: 1.381459e+03,train_penalty: 2.386856e-03,
# Epoch 93, batch 4/13,train_objective: 1.381584e+03,train_penalty: 2.392006e-03,
# Epoch 93, batch 5/13,train_objective: 1.382297e+03,train_penalty: 2.389118e-03,
# Epoch 93, batch 6/13,train_objective: 1.383228e+03,train_penalty: 2.385378e-03,
# Epoch 93, batch 7/13,train_objective: 1.383772e+03,train_penalty: 2.376476e-03,
# Epoch 93, batch 8/13,train_objective: 1.384136e+03,train_penalty: 2.374413e-03,
# Epoch 93, batch 9/13,train_objective: 1.384897e+03,train_penalty: 2.370969e-03,
# Epoch 93, batch 10/13,train_objective: 1.385143e+03,train_penalty: 2.369911e-03,
# Epoch 93, batch 10/13,train_objective: 1.385143e+03,train_penalty: 2.369911e-03,val_objective: 1.465966e+03,val_penalty: 3.360158e-03
# Epoch 93, batch 11/13,train_objective: 2.764360e+03,train_penalty: 4.689575e-03,
# Epoch 93, batch 12/13,train_objective: 2.069409e+03,train_penalty: 3.481054e-03,
# Epoch 93, batch 13/13,train_objective: 1.839392e+03,train_penalty: 3.085803e-03,
# Epoch 94, batch 1/13,train_objective: 1.380510e+03,train_penalty: 2.306613e-03,
# Epoch 94, batch 2/13,train_objective: 1.380038e+03,train_penalty: 2.283895e-03,
# Epoch 94, batch 3/13,train_objective: 1.378468e+03,train_penalty: 2.303653e-03,
# Epoch 94, batch 4/13,train_objective: 1.377378e+03,train_penalty: 2.312334e-03,
# Epoch 94, batch 5/13,train_objective: 1.374612e+03,train_penalty: 2.297675e-03,
# Epoch 94, batch 6/13,train_objective: 1.374470e+03,train_penalty: 2.290967e-03,
# Epoch 94, batch 7/13,train_objective: 1.374609e+03,train_penalty: 2.288619e-03,
# Epoch 94, batch 8/13,train_objective: 1.373538e+03,train_penalty: 2.292881e-03,
# Epoch 94, batch 9/13,train_objective: 1.372245e+03,train_penalty: 2.289826e-03,
# Epoch 94, batch 10/13,train_objective: 1.371637e+03,train_penalty: 2.292050e-03,
# Epoch 94, batch 10/13,train_objective: 1.371637e+03,train_penalty: 2.292050e-03,val_objective: 1.490785e+03,val_penalty: 1.067513e-02
# Epoch 94, batch 11/13,train_objective: 2.735341e+03,train_penalty: 4.511454e-03,
# Epoch 94, batch 12/13,train_objective: 2.045432e+03,train_penalty: 3.405935e-03,
# Epoch 94, batch 13/13,train_objective: 1.816311e+03,train_penalty: 3.019945e-03,
# Epoch 95, batch 1/13,train_objective: 1.354192e+03,train_penalty: 2.267522e-03,
# Epoch 95, batch 2/13,train_objective: 1.355049e+03,train_penalty: 2.258172e-03,
# Epoch 95, batch 3/13,train_objective: 1.354644e+03,train_penalty: 2.247025e-03,
# Epoch 95, batch 4/13,train_objective: 1.354295e+03,train_penalty: 2.245945e-03,
# Epoch 95, batch 5/13,train_objective: 1.354593e+03,train_penalty: 2.240875e-03,
# Epoch 95, batch 6/13,train_objective: 1.354797e+03,train_penalty: 2.239277e-03,
# Epoch 95, batch 7/13,train_objective: 1.354261e+03,train_penalty: 2.250005e-03,
# Epoch 95, batch 8/13,train_objective: 1.354203e+03,train_penalty: 2.249812e-03,
# Epoch 95, batch 9/13,train_objective: 1.355480e+03,train_penalty: 2.243953e-03,
# Epoch 95, batch 10/13,train_objective: 1.356995e+03,train_penalty: 2.239535e-03,
# Epoch 95, batch 10/13,train_objective: 1.356995e+03,train_penalty: 2.239535e-03,val_objective: 1.495755e+03,val_penalty: 1.282564e-02
# Epoch 95, batch 11/13,train_objective: 2.750463e+03,train_penalty: 4.534301e-03,
# Epoch 95, batch 12/13,train_objective: 2.080200e+03,train_penalty: 3.380038e-03,
# Epoch 95, batch 13/13,train_objective: 1.867080e+03,train_penalty: 3.008798e-03,
# Epoch 96, batch 1/13,train_objective: 1.438367e+03,train_penalty: 2.243792e-03,
# Epoch 96, batch 2/13,train_objective: 1.426332e+03,train_penalty: 2.257899e-03,
# Epoch 96, batch 3/13,train_objective: 1.419236e+03,train_penalty: 2.262729e-03,
# Epoch 96, batch 4/13,train_objective: 1.416979e+03,train_penalty: 2.269301e-03,
# Epoch 96, batch 5/13,train_objective: 1.415666e+03,train_penalty: 2.272451e-03,
# Epoch 96, batch 6/13,train_objective: 1.410977e+03,train_penalty: 2.276839e-03,
# Epoch 96, batch 7/13,train_objective: 1.406116e+03,train_penalty: 2.278734e-03,
# Epoch 96, batch 8/13,train_objective: 1.403815e+03,train_penalty: 2.285693e-03,
# Epoch 96, batch 9/13,train_objective: 1.402434e+03,train_penalty: 2.294284e-03,
# Epoch 96, batch 10/13,train_objective: 1.399048e+03,train_penalty: 2.296733e-03,
# Epoch 96, batch 10/13,train_objective: 1.399048e+03,train_penalty: 2.296733e-03,val_objective: 1.487139e+03,val_penalty: 1.796148e-02
# Epoch 96, batch 11/13,train_objective: 2.768404e+03,train_penalty: 4.546002e-03,
# Epoch 96, batch 12/13,train_objective: 2.070731e+03,train_penalty: 3.391805e-03,
# Epoch 96, batch 13/13,train_objective: 1.833266e+03,train_penalty: 3.071479e-03,
# Epoch 97, batch 1/13,train_objective: 1.356205e+03,train_penalty: 2.316168e-03,
# Epoch 97, batch 2/13,train_objective: 1.356414e+03,train_penalty: 2.305343e-03,
# Epoch 97, batch 3/13,train_objective: 1.356864e+03,train_penalty: 2.326309e-03,
# Epoch 97, batch 4/13,train_objective: 1.355573e+03,train_penalty: 2.325745e-03,
# Epoch 97, batch 5/13,train_objective: 1.355460e+03,train_penalty: 2.322183e-03,
# Epoch 97, batch 6/13,train_objective: 1.354597e+03,train_penalty: 2.313034e-03,
# Epoch 97, batch 7/13,train_objective: 1.353600e+03,train_penalty: 2.308470e-03,
# Epoch 97, batch 8/13,train_objective: 1.353112e+03,train_penalty: 2.308067e-03,
# Epoch 97, batch 9/13,train_objective: 1.352798e+03,train_penalty: 2.307386e-03,
# Epoch 97, batch 10/13,train_objective: 1.352748e+03,train_penalty: 2.304140e-03,
# Epoch 97, batch 10/13,train_objective: 1.352748e+03,train_penalty: 2.304140e-03,val_objective: 1.483180e+03,val_penalty: 6.513731e-03
# Epoch 97, batch 11/13,train_objective: 2.692880e+03,train_penalty: 4.623717e-03,
# Epoch 97, batch 12/13,train_objective: 2.016053e+03,train_penalty: 3.432907e-03,
# Epoch 97, batch 13/13,train_objective: 1.792396e+03,train_penalty: 3.039131e-03,
# Epoch 98, batch 1/13,train_objective: 1.342665e+03,train_penalty: 2.247486e-03,
# Epoch 98, batch 2/13,train_objective: 1.334270e+03,train_penalty: 2.217641e-03,
# Epoch 98, batch 3/13,train_objective: 1.335668e+03,train_penalty: 2.216924e-03,
# Epoch 98, batch 4/13,train_objective: 1.338176e+03,train_penalty: 2.219494e-03,
# Epoch 98, batch 5/13,train_objective: 1.338999e+03,train_penalty: 2.200504e-03,
# Epoch 98, batch 6/13,train_objective: 1.340616e+03,train_penalty: 2.183613e-03,
# Epoch 98, batch 7/13,train_objective: 1.343395e+03,train_penalty: 2.185632e-03,
# Epoch 98, batch 8/13,train_objective: 1.347507e+03,train_penalty: 2.183617e-03,
# Epoch 98, batch 9/13,train_objective: 1.351679e+03,train_penalty: 2.168850e-03,
# Epoch 98, batch 10/13,train_objective: 1.355837e+03,train_penalty: 2.160487e-03,
# Epoch 98, batch 10/13,train_objective: 1.355837e+03,train_penalty: 2.160487e-03,val_objective: 1.854955e+03,val_penalty: 1.280622e-02
# Epoch 98, batch 11/13,train_objective: 2.767613e+03,train_penalty: 4.302337e-03,
# Epoch 98, batch 12/13,train_objective: 2.094454e+03,train_penalty: 3.194995e-03,
# Epoch 98, batch 13/13,train_objective: 1.872465e+03,train_penalty: 2.808016e-03,
# Epoch 99, batch 1/13,train_objective: 1.395936e+03,train_penalty: 2.010837e-03,
# Epoch 99, batch 2/13,train_objective: 1.381111e+03,train_penalty: 2.028821e-03,
# Epoch 99, batch 3/13,train_objective: 1.371680e+03,train_penalty: 2.034762e-03,
# Epoch 99, batch 4/13,train_objective: 1.367556e+03,train_penalty: 2.022622e-03,
# Epoch 99, batch 5/13,train_objective: 1.371016e+03,train_penalty: 2.018069e-03,
# Epoch 99, batch 6/13,train_objective: 1.373497e+03,train_penalty: 2.008571e-03,
# Epoch 99, batch 7/13,train_objective: 1.373956e+03,train_penalty: 2.015036e-03,
# Epoch 99, batch 8/13,train_objective: 1.372843e+03,train_penalty: 2.016356e-03,
# Epoch 99, batch 9/13,train_objective: 1.371523e+03,train_penalty: 2.011790e-03,
# Epoch 99, batch 10/13,train_objective: 1.371222e+03,train_penalty: 2.006764e-03,
# Epoch 99, batch 10/13,train_objective: 1.371222e+03,train_penalty: 2.006764e-03,val_objective: 1.448093e+03,val_penalty: 3.328829e-03
# Epoch 99, batch 11/13,train_objective: 2.718777e+03,train_penalty: 3.997814e-03,
# Epoch 99, batch 12/13,train_objective: 2.030574e+03,train_penalty: 3.005244e-03,
# Epoch 99, batch 13/13,train_objective: 1.807144e+03,train_penalty: 2.659656e-03,

# %%
ls
# Out:
# data/                                  vae_dilated_e_047_loss_7.4994e+03.pkl
# gdrive/                                vae_dilated_e_048_loss_7.4121e+03.pkl
# sample_data/                           vae_dilated_e_049_loss_7.4530e+03.pkl
# vae_dilated_e_000_loss_1.7390e+05.pkl  vae_dilated_e_050_loss_7.2876e+03.pkl
# vae_dilated_e_000_loss_2.1543e+05.pkl  vae_dilated_e_051_loss_7.2472e+03.pkl
# vae_dilated_e_000_loss_2.4455e+05.pkl  vae_dilated_e_052_loss_7.1110e+03.pkl
# vae_dilated_e_000_loss_6.7717e+05.pkl  vae_dilated_e_053_loss_7.2670e+03.pkl
# vae_dilated_e_001_loss_1.1157e+05.pkl  vae_dilated_e_054_loss_7.0138e+03.pkl
# vae_dilated_e_001_loss_2.9837e+05.pkl  vae_dilated_e_055_loss_6.9026e+03.pkl
# vae_dilated_e_002_loss_5.6187e+04.pkl  vae_dilated_e_056_loss_6.9308e+03.pkl
# vae_dilated_e_003_loss_3.7112e+04.pkl  vae_dilated_e_057_loss_6.9630e+03.pkl
# vae_dilated_e_004_loss_3.0005e+04.pkl  vae_dilated_e_058_loss_6.7679e+03.pkl
# vae_dilated_e_005_loss_2.7753e+04.pkl  vae_dilated_e_059_loss_6.7850e+03.pkl
# vae_dilated_e_006_loss_2.5724e+04.pkl  vae_dilated_e_060_loss_6.7151e+03.pkl
# vae_dilated_e_007_loss_2.2732e+04.pkl  vae_dilated_e_061_loss_6.6123e+03.pkl
# vae_dilated_e_008_loss_2.3786e+04.pkl  vae_dilated_e_062_loss_6.5389e+03.pkl
# vae_dilated_e_009_loss_1.9941e+04.pkl  vae_dilated_e_063_loss_6.6443e+03.pkl
# vae_dilated_e_010_loss_1.7559e+04.pkl  vae_dilated_e_064_loss_6.4536e+03.pkl
# vae_dilated_e_011_loss_1.6113e+04.pkl  vae_dilated_e_065_loss_6.7443e+03.pkl
# vae_dilated_e_012_loss_1.5094e+04.pkl  vae_dilated_e_066_loss_6.4084e+03.pkl
# vae_dilated_e_013_loss_1.4238e+04.pkl  vae_dilated_e_067_loss_6.2876e+03.pkl
# vae_dilated_e_014_loss_1.3793e+04.pkl  vae_dilated_e_068_loss_6.5548e+03.pkl
# vae_dilated_e_015_loss_1.3072e+04.pkl  vae_dilated_e_069_loss_6.2969e+03.pkl
# vae_dilated_e_016_loss_1.3005e+04.pkl  vae_dilated_e_070_loss_6.1691e+03.pkl
# vae_dilated_e_017_loss_1.2211e+04.pkl  vae_dilated_e_071_loss_6.3382e+03.pkl
# vae_dilated_e_018_loss_1.2587e+04.pkl  vae_dilated_e_072_loss_6.3112e+03.pkl
# vae_dilated_e_019_loss_1.1755e+04.pkl  vae_dilated_e_073_loss_6.0887e+03.pkl
# vae_dilated_e_020_loss_1.1265e+04.pkl  vae_dilated_e_074_loss_6.0031e+03.pkl
# vae_dilated_e_021_loss_1.1356e+04.pkl  vae_dilated_e_075_loss_6.0823e+03.pkl
# vae_dilated_e_022_loss_1.0784e+04.pkl  vae_dilated_e_076_loss_5.9516e+03.pkl
# vae_dilated_e_023_loss_1.0818e+04.pkl  vae_dilated_e_077_loss_5.9221e+03.pkl
# vae_dilated_e_024_loss_1.0388e+04.pkl  vae_dilated_e_078_loss_5.9340e+03.pkl
# vae_dilated_e_025_loss_1.0127e+04.pkl  vae_dilated_e_079_loss_5.8436e+03.pkl
# vae_dilated_e_026_loss_1.0646e+04.pkl  vae_dilated_e_080_loss_5.9538e+03.pkl
# vae_dilated_e_027_loss_9.9821e+03.pkl  vae_dilated_e_081_loss_5.7915e+03.pkl
# vae_dilated_e_028_loss_9.6748e+03.pkl  vae_dilated_e_082_loss_5.7691e+03.pkl
# vae_dilated_e_029_loss_9.4770e+03.pkl  vae_dilated_e_083_loss_5.8362e+03.pkl
# vae_dilated_e_030_loss_1.0221e+04.pkl  vae_dilated_e_084_loss_5.7150e+03.pkl
# vae_dilated_e_031_loss_9.4548e+03.pkl  vae_dilated_e_085_loss_5.7384e+03.pkl
# vae_dilated_e_032_loss_9.1479e+03.pkl  vae_dilated_e_086_loss_5.9428e+03.pkl
# vae_dilated_e_033_loss_8.9195e+03.pkl  vae_dilated_e_087_loss_5.6735e+03.pkl
# vae_dilated_e_034_loss_8.9237e+03.pkl  vae_dilated_e_088_loss_5.5755e+03.pkl
# vae_dilated_e_035_loss_8.8863e+03.pkl  vae_dilated_e_089_loss_5.6820e+03.pkl
# vae_dilated_e_036_loss_8.5892e+03.pkl  vae_dilated_e_090_loss_5.5542e+03.pkl
# vae_dilated_e_037_loss_8.6302e+03.pkl  vae_dilated_e_091_loss_5.6529e+03.pkl
# vae_dilated_e_038_loss_8.3516e+03.pkl  vae_dilated_e_092_loss_5.5386e+03.pkl
# vae_dilated_e_039_loss_8.3469e+03.pkl  vae_dilated_e_093_loss_5.5182e+03.pkl
# vae_dilated_e_040_loss_8.1659e+03.pkl  vae_dilated_e_094_loss_5.4489e+03.pkl
# vae_dilated_e_041_loss_8.2309e+03.pkl  vae_dilated_e_095_loss_5.6012e+03.pkl
# vae_dilated_e_042_loss_8.0482e+03.pkl  vae_dilated_e_096_loss_5.4998e+03.pkl
# vae_dilated_e_043_loss_7.8418e+03.pkl  vae_dilated_e_097_loss_5.3772e+03.pkl
# vae_dilated_e_044_loss_7.9033e+03.pkl  vae_dilated_e_098_loss_5.6174e+03.pkl
# vae_dilated_e_045_loss_8.2583e+03.pkl  vae_dilated_e_099_loss_5.4214e+03.pkl
# vae_dilated_e_046_loss_7.6873e+03.pkl
